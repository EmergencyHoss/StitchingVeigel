# %%
import sys
import os

# Add the path to the Utils directory
sys.path.append(os.path.abspath("../src/Utils"))

# Now you can import your module
import utils

# %%
utils.read_parquet_file("..\data\parquet\episode_002011.parquet")
# Out:
#                              observation.state.vehicle  \
# 0    [87.22656, 84.831604, 0.19136, 48.72275, 13.53...
# 1    [87.22656, 84.45853, 0.18346, 48.72275, 13.537...
# 2    [87.32031, 84.25415, 0.18124, 48.722755, 13.53...
# 3    [87.296875, 83.57974, 0.18707, 48.72276, 13.53...
# 4    [87.50781, 83.7749, 0.19031, 48.72276, 13.5378...
# ..                                                 ...
# 295  [76.640625, 66.93967, 0.19443, 48.726364, 13.5...
# 296  [76.78906, 67.01236, 0.19558, 48.72637, 13.544...
# 297  [76.92969, 67.219055, 0.19585, 48.72638, 13.54...
# 298  [76.9375, 67.611755, 0.1926, 48.726387, 13.545...
# 299  [77.078125, 67.829346, 0.19236, 48.72639, 13.5...
#
#                            observation.state.waypoints  \
# 0    [[13.537808, 48.72277], [13.537943, 48.72278],...
# 1    [[13.537808, 48.72277], [13.537943, 48.72278],...
# 2    [[13.537808, 48.72277], [13.537943, 48.72278],...
# 3    [[13.537943, 48.72278], [13.538077, 48.722794]...
# ...

# %%
utils.extract_frames_from_video(video_path=r"..\data\videos\3900001421.mp4", output_dir=r"..\data\images")

# %%
utils.create_video_from_images(image_folder=r"..\stitched", output_dir=r"..\data\videos")
# Out:
# ✅ Video saved to: ..\data\videos\stitched.mp4

# %%
utils.convert_mkv_to_mp4(input_path=r"..\data\videos\video1\out1.mkv", output_dir=r"..\data\videos\video1")
# Out:
# MoviePy - Building video ..\data\videos\video1\out7.mp4.
# MoviePy - Writing video ..\data\videos\video1\out7.mp4
# MoviePy - Done !
# MoviePy - video ready ..\data\videos\video1\out7.mp4
# ✅ Conversion successful: ..\data\videos\video1\out7.mp4

# %%
utils.resize_and_crop_images(input_folder=r"..\data\images\test_small\test\video2", output_folder=r"..\data\images\test_small\small\video2")
# Out:
# ['..\\data\\images\\test_small\\test\\frame_00100.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00101.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00102.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00103.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00104.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00105.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00106.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00107.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00108.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00109.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00110.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00111.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00112.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00113.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00114.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00115.jpg',
#  '..\\data\\images\\test_small\\test\\frame_00116.jpg',
# ...
